# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

# create data
np.random.seed(42)
X = 2 * np.random.randn(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# visualize data 
plt.scatter(X, y)
plt.title('generated data points')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# cost function
def compute_cost(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1/(2*m)) * np.sum(np.square(predictions - y))
    return cost

# gradien descent

def gradient_descent(X, y, theta):
    m = len(y)
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = predictions - y
        theta = theta - (1/m) * learning_rate * (X.T.dot(errors))
        cost_history[i] = compute_cost(X, yb, theta)

    return theta, cost_history

#
X_b = np.c_[np.ones((100, 1)), X]

# select two different initial point
theta_initial_1 = np.array([[0.5], [0.5]]) 
theat_initial_2 = np.array([[2.0], [2.0]])

# first training with gradient descent
learning_rate = 0.01
iterations = 1000
theta_final_1, cost_history_1 = gradient_descent(X_b, y, theta_initial_1, learning_rate, iterations)

# second training with gradient descent
theta_final_2, cost_history_2 = gradient_descent(X_b, y, theta_initial_2, learning_rate, iterations)

# visualizing the trainig procress
plt.plot(range(1, iterations + 1), cost_history_1, label='Starting Point 1')
plt.plot(range(1, iterations + 1), cost_history_2, label='Starting Point 2')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Training Process with Gradient Descent')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 49
#      47 learning_rate = 0.01
#      48 iterations = 1000
# ---> 49 theta_final_1, cost_history_1 = gradient_descent(X_b, y, theta_initial_1, learning_rate, iterations)
#      51 # second training with gradient descent
#      52 theta_final_2, cost_history_2 = gradient_descent(X_b, y, theta_initial_2, learning_rate, iterations)
#
# TypeError: gradient_descent() takes 3 positional arguments but 5 were given

# %%
import matplotlib.pyplot as plt
import numpy as np

# create data
np.random.seed(42)
X = 2 * np.random.randn(100, 1)
y = 4 + 3 * X + np.random.randn(100, 1)

# visualize data
plt.scatter(X, y)
plt.title('Generated Data Points')
plt.xlabel('X')
plt.ylabel('y')
plt.show()

# cost function
def compute_cost(X, y, theta):
    m = len(y)
    predictions = X.dot(theta)
    cost = (1/(2*m)) * np.sum(np.square(predictions - y))
    return cost

# gradient descent
def gradient_descent(X, y, theta, learning_rate, iterations):
    m = len(y)
    cost_history = np.zeros(iterations)

    for i in range(iterations):
        predictions = X.dot(theta)
        errors = predictions - y
        theta = theta - (1/m) * learning_rate * (X.T.dot(errors))
        cost_history[i] = compute_cost(X, y, theta)

    return theta, cost_history

# 
X_b = np.c_[np.ones((100, 1)), X]

# iki farklı başlangıç noktası seçme
theta_initial_1 = np.array([[0.5], [0.5]])
theta_initial_2 = np.array([[2.0], [2.0]])

# first training with gradient descent
learning_rate = 0.01
iterations = 1000
theta_final_1, cost_history_1 = gradient_descent(X_b, y, theta_initial_1, learning_rate, iterations)

# second training with gradient descent
theta_final_2, cost_history_2 = gradient_descent(X_b, y, theta_initial_2, learning_rate, iterations)

# Visualing tn training process
plt.plot(range(1, iterations + 1), cost_history_1, label='Starting Point 1')
plt.plot(range(1, iterations + 1), cost_history_2, label='Starting Point 2')
plt.grid()
plt.xlabel('Iterations')
plt.ylabel('Cost')
plt.title('Training Process wit Gradient Descent')
plt.legend()
plt.show()
