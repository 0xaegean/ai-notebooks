# %%
import matplotlib.pyplot as plt
import numpy as np

import matplotlib as mpl

# %%
def function(x):
    return x**2

def gradient(x):
    return 2*x

def gradient_descent(learning_rate, iterations):
    x = 4 # başlangıç noktası
    x_values = [x]

    for _ in range(iterations):
        grad = gradient(x)
        x = x - learning_rate * grad
        x_values. append(x)

    return x_values

learning_rate = 0.1
iterations = 10
x_values = gradient_descent(learning_rate, iterations)

# %%
# function graph
x_range = np.linspace(-2, 5, 100)
plt.plot(x_range, function(x_range), label='f(x) = x^2')

# %%
# gradient descent steps
plt.scatter(x_values, [function(x) for x in x_values], color='red', label='Gradient Descent Steps')
plt.plot(x_values, [function(x) for x in x_values], linestyle='dashed', color='red')

# %%
# başlangıç noktası and minimum
plt.scatter(x_values[0], function(x_values[0]), color='green', label='Starting Point')
plt.scatter(x_values[-1], function(x_values[-1]), color='blue', label='Minimum Point')

# %%
plt.title('Gradient Descent')
plt.xlabel('X')
plt.ylabel('y')
plt.plot(X, y)
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 4
#       2 plt.xlabel('X')
#       3 plt.ylabel('y')
# ----> 4 plt.plot(X, y)
#       5 plt.legend()
#       6 plt.show()
#
# NameError: name 'X' is not defined
